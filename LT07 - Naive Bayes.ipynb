# %% [markdown]
# ### Giới thiệu về Thuật toán Naive Bayes
# Naive Bayes là một thuật toán học máy dựa trên Định lý Bayes. Nó được gọi là "Naive" vì giả định rằng tất cả các thuộc tính (features) là độc lập có điều kiện với nhau khi biết nhãn (class). Đây là một thuật toán phân loại hiệu quả và nhanh, đặc biệt phù hợp với các bài toán phân loại văn bản, email spam, và nhiều bài toán phân loại khác.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Bài tập hướng dẫn

# %% [markdown]
# **Đề Bài**
#
# ![image-2.png](attachment:image-2.png)
#
# Hôm nay **Thời tiết = Nắng** và **Sức khỏe = Ốm**, dự đoán có nghỉ học không?

# %% [markdown]
# **Bài làm**
#
#
# ![image-3.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Vậy ta có
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
